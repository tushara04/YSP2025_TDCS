# %% [markdown]
# #Targeted Travel Ads#

# %% [markdown]
# You have been recruited by a travel agency to advertise its travel plans to people who use the agency's partner websites.
#
# #Target Identification#
#
# The first step towards advertising is to know who you are advertising to. Suppose you have received a list of users of your partner websites who could be your target demographic.
#
#
# *   amuro1979
# *   zeta_kamille
# *   judauashta
# *   pilot4unicorn
# *   mafty
#
# Add these users to your target database.
#
# 🔧 Bonus: Try including other attributes of these users, such as age, city, interests, etc. into your database. This will be helpful in later steps.

# %%
targetusers = []

# %% [markdown]
# # Interest Identification #
#
# Now that you have a list of people to target your ads towards, the next step is to understand whether this person fits the demographic you are capable of serving. The factors include but may not be limited to the following:
#
# *   You cannot sell travel plans to anyone below the age of 16.
# *   A person would not seek a travel agency to visit their hometown.
# *   A person would only seek to go to a particular place if it aligns with their interests.
#
#
# In your database, suppose you have the age, the howntown, and the interest of the potential targets.
#
# (If you attempted the bonus part, it might look something like this)
#
# ```
# [judauashta, 14, Shangri-La, antiques]
# ```
#
# Retrive each attribute of the users so that you can evaluate whether you can target ads towards them or not.
#
# 🔧 Bonus: Delete those who do not fit the factors.
#
# 🔧 Challenge: Suppose your travel agency has decided that for some time, it will cater to only people with a particular combination of interests, such as "antiques and Asian culture". You have only collected the primary interest of users so far. Accomodate multiple interests in your database.

# %% [markdown]
# # Picking up keywords #
#
# By now you must have realised how many of the users from the initial list are actually targetable. However, if you start showing ads to them with such a shallow idea of them, they may not react to those ads positively. You must get to know where your target wants to go, how much your target is capable of spending on a trip, or how many people they wish to go with. The precision of ads are crutial to their performance.
#
# The next step is to read your target's comments on your partner websites to understand your target better. Suppose your agency has a travel plan for Japan. You need to know if your target discusses Japanese culture, and whether it is in a positive or a negative light.
#
# ‼️ Hints:
# *  A person may not mention Japan directly but could still be talking about it.
#
# *  Since we are only concerned with Japan at the moment, try to look past your target's negative opinions towards other things.
#
# *  Your agency operates under the law. Do not encourage your target's criminal tendencies, if there are any.

# %%
comments = ["The samurai were so cool.","I think sushi tastes very bad.", "I hate dancing.","Tokyo must be a fun","I wanna join the yakuza.","Anime is my life I swear."]
